# %%
! pip install langchain-groq -q
! pip install langchain-community -q
! pip install langchain-core -q
! pip install langchain-chroma -q
! pip install beautifulsoup4 -q
! pip install langchain-huggingface -q
! pip install sentence-transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.9/393.9 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 47.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.6 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(groq_api_key="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",model_name="Llama3-8b-8192")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x78416cbaf5e0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x78416cc0fd30>, model_name='Llama3-8b-8192', groq_api_key=SecretStr('**********'))

# %%
from langchain_huggingface import HuggingFaceEmbeddings
HUGGINGFACE_TOKEN = "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"
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

loader = RecursiveUrlLoader("https://www.datanetiix.com/",)
docs = loader.load()
docs[0].metadata
# Out:
# WARNING:langchain_community.document_loaders.recursive_url_loader:Unable to load from https://www.datanetiix.com/marketing-cloud.php. Received error HTTPSConnectionPool(host='www.datanetiix.com', port=443): Read timed out. (read timeout=10) of type ReadTimeout
# {'source': 'https://www.datanetiix.com/',
#  'content_type': 'text/html; charset=UTF-8',
#  'title': 'For your Software Development, Business Intelligence & IT needs',
#  'description': 'Datanetiix is a One-Stop-Solution provider for Software Development, Customized applications, Business Intelligence & IT needs. We provide end-to-end solutions ranging from Customized solutions – mobile app, web apps, ERP – Microsoft Dynamics, Salesforce Cloud solutions and Collaboration tools. With over a decade in the industry, we have extensive experience serving global clients across numerous Industries.',
#  'language': 'en'}

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma

text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=100)
splits=text_splitter.split_documents(docs)
vectorstore=Chroma.from_documents(documents=splits,embedding=embeddings)
retriever=vectorstore.as_retriever()
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'HuggingFaceEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x7840394e3fd0>)

# %%
## Prompt Template
from langchain_core.prompts import ChatPromptTemplate

system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

question_answer_chain=create_stuff_documents_chain(llm,prompt)
rag_chain=create_retrieval_chain(retriever,question_answer_chain)

# %%
response=rag_chain.invoke({"input":"What is Datanetiix"})
response['answer']
# Out:
# 'Datanetiix is a consulting and technology partner that provides end-to-end services in various areas, including Business Solutions, Microsoft Dynamics, Salesforce, Collaboration tools, Digital Transformation, Mobility Solutions, and Quality Assurance.'

# %%
response=rag_chain.invoke({"input":"Where datanetiix is located"})
response['answer']
# Out:
# 'Datanetiix is located at 19800 MacArthur Blvd, #300, Irvine, California 92612, United States of America.'

# %%
response=rag_chain.invoke({"input":"Is they providing AI/ML solutions?"})
response['answer']
# Out:
# 'Yes, Datanetiix provides AI and Machine Learning (ML) consulting services, which enable businesses to deliver tailored customer experiences, automate internal processes, and execute solutions that transform customer-product relationships. Their data scientists and AI developers develop technology-independent data-driven solutions to help organizations restructure their systems or boost the functionality of their current platforms by integrating artificial intelligence business solutions.'

# %%
response=rag_chain.invoke({"input":"Currently they are hiring react JS developers?"})
response['answer']
# Out:
# 'Yes, according to the provided context, they are hiring ReactJS developers with experience in building web applications, familiarity with JavaScript ES6, Grunt, Webpack & AMD, and knowledge of linking 3rd party modules in ReactJS.'

# %%
response=rag_chain.invoke({"input":"Give me the contact number for Datanetiix"})
response['answer']
# Out:
# 'The contact number for Datanetiix is 949-340-2540.'
